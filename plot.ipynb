# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
accuracy = [0.9417040358744395, 0.6771894093686355,0.8195067264573991,0.27802690582959644] # class 5, single SinGAN
acc_labels = ['full dataset','imbalanced','baseline','SinGAN']

# %%
fig = plt.figure()
ax = plt.gca()
ax.bar(acc_labels, accuracy)
fig.suptitle('Test Accuracy on Imbalanced Class')
# Out:
# Text(0.5, 0.98, 'Test Accuracy on Imbalanced Class')

# %%
ssim = [0.23753565018518835, 0.10891037505014035, 0.9266272143714874]  # class 5, single SinGAN
ssim_labels = ['reference','baseline', 'SinGAN']

# %%
fig = plt.figure()
ax = plt.gca()
ax.bar(ssim_labels, ssim)
fig.suptitle('SSIM on Generated Data')
# Out:
# Text(0.5, 0.98, 'SSIM on Generated Data')

# %%
accuracy = [0.9765784114052953, 0.6771894093686355,0.7423625254582484,0.8564154786150713,0.7871690427698574] # class 4, 59 SinGAN
acc_labels = ['full dataset','imbalanced','baseline','BAGAN','SinGAN']

fig = plt.figure()
ax = plt.gca()
ax.bar(acc_labels, accuracy)
fig.suptitle('Test Accuracy on Imbalanced Class')
# Out:
# Text(0.5, 0.98, 'Test Accuracy on Imbalanced Class')

# %%
ssim = [0.27729570652762636, 0.1689696568210068,0.33242153462871565, 0.2825011128378561
]  # class 4, 147 SinGAN
ssim_labels = ['reference','baseline', 'BAGAN','SinGAN']
fig = plt.figure()
ax = plt.gca()
ax.bar(ssim_labels, ssim)
fig.suptitle('SSIM on Generated Data')
# Out:
# Text(0.5, 0.98, 'SSIM on Generated Data')
